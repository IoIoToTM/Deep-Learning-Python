# %%
import os, cv2, random
import numpy as np
import sys, time
from IPython.core.display import clear_output
import matplotlib.pyplot as plt

# %%
TRAIN_DIR_DOG = 'data/train/dogs/'
TRAIN_DIR_CAT = 'data/train/cats/'
TEST_DIR = 'data/test/'

# %%
ROWS = 256
COLS = 256
ROWS2 = 64
COLS2 = 64
CHANNELS = 3

# %%
train_dogs =   [TRAIN_DIR_DOG+i for i in os.listdir(TRAIN_DIR_DOG) if 'dog' in i]
train_cats =   [TRAIN_DIR_CAT+i for i in os.listdir(TRAIN_DIR_CAT) if 'cat' in i]

test_images =  [TEST_DIR+i for i in os.listdir(TEST_DIR)]

# %%
train_images = train_dogs + train_cats
random.shuffle(train_images)
random.shuffle(test_images)
test2_images = test_images[0:20]

# %%
def read_image(file_path):
    img = cv2.imread(file_path, cv2.IMREAD_COLOR)
    b,g,r = cv2.split(img)
    img2 = cv2.merge([r,g,b])
    return cv2.resize(img2, (ROWS2, COLS2), interpolation=cv2.INTER_CUBIC)

def read_image2(file_path):
    img = cv2.imread(file_path, cv2.IMREAD_COLOR)
    b,g,r = cv2.split(img)
    img2 = cv2.merge([r,g,b])
    return cv2.resize(img2, (ROWS, COLS), interpolation=cv2.INTER_CUBIC)

# %%
def prep_data(images):
    count = len(images)
    data = np.ndarray((count, CHANNELS, ROWS2, COLS2), dtype=np.uint8)

    for i, image_file in enumerate(images):
        image = read_image(image_file)
        data[i] = image.T
        if i%1000 == 0: 

            print('Processed {} of {}'.format(i, count))
    
    return data

def prep_data2(images):
    count = len(images)
    data = np.ndarray((count, CHANNELS, ROWS, COLS), dtype=np.uint8)

    for i, image_file in enumerate(images):
        image = read_image2(image_file)
        data[i] = image.T
        if i%2 == 0: print('Processed {} of {}'.format(i, count))
    
    return data

# %%
train = prep_data(train_images)
test = prep_data(test_images)
test2 = prep_data2(test2_images)
# Out:
# Processed 0 of 8000
# Processed 1000 of 8000
# Processed 2000 of 8000
# Processed 3000 of 8000
# Processed 4000 of 8000
# Processed 5000 of 8000
# Processed 6000 of 8000
# Processed 7000 of 8000
# Processed 0 of 1800
# Processed 1000 of 1800
# Processed 0 of 20
# Processed 2 of 20
# Processed 4 of 20
# Processed 6 of 20
# Processed 8 of 20
# Processed 10 of 20
# Processed 12 of 20
# Processed 14 of 20
# Processed 16 of 20
# Processed 18 of 20

# %%
print("Train shape: {}".format(train.shape))
print("Test shape: {}".format(test.shape))
print("Test shape: {}".format(test2.shape))
# Out:
# Train shape: (8000, 3, 64, 64)
# Test shape: (1800, 3, 64, 64)
# Test shape: (20, 3, 256, 256)

# %%
labels = []
for i in train_images:
    if 'dog' in i:
        labels.append(1)
    else:
        labels.append(0)

# %%
from keras.models import Sequential
from keras.layers import Input, Dropout, Flatten, Conv2D, MaxPooling2D, Dense, Activation
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from keras.utils import np_utils

optimizer = RMSprop(lr=1e-4)
objective = 'binary_crossentropy'
# Out:
# Using TensorFlow backend.

# %%
def catdog():
    
    model = Sequential()

    model.add(Conv2D(32, 3, padding='same', input_shape=train.shape[1:], activation='relu'))
    model.add(Conv2D(32, 3, padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), data_format="channels_first"))

    model.add(Conv2D(64, 3, padding='same', activation='relu'))
    model.add(Conv2D(64, 3, padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), data_format="channels_first"))

    model.add(Conv2D(128, 3, padding='same', activation='relu'))
    model.add(Conv2D(128, 3, padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), data_format="channels_first"))

    model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), data_format="channels_first"))

    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(1))
    model.add(Activation('sigmoid'))
    model.compile(loss=objective, optimizer=optimizer, metrics=['accuracy'])
    return model

# %%
model = catdog()

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 3, 64, 32)         18464
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 64, 32)         9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 3, 32, 16)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 32, 64)         9280
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 3, 32, 64)         36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 16, 32)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 3, 16, 128)        36992
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 3, 16, 128)        147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 8, 64)          0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 3, 8, 256)         147712
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 3, 8, 256)         590080
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 3, 8, 256)         590080
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 3, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1536)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               393472
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 2,045,889
# Trainable params: 2,045,889
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 50
batch_size = 50

# %%
class LossHistory(Callback):
    def on_train_begin(self, logs={}):
        self.losses = []
        self.val_losses = []
        
    def on_epoch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))
        self.val_losses.append(logs.get('val_loss'))

early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, mode='auto')

# %%
def run_catdog():
    
    history = LossHistory()
    print("running model...")
    model.fit(train, labels, batch_size=batch_size, epochs=epochs,
            validation_split=0.25, verbose=2, shuffle=True, callbacks=[history, early_stopping])
            #validation_split=0.25, verbose=2, shuffle=True, callbacks=[history])
    
    print("making predictions on test set...")
    predictions = model.predict(test, verbose=0)
    return predictions, history

# %%
predictions, history = run_catdog()

loss = history.losses
val_loss = history.val_losses
# Out:
# running model...
# Train on 6000 samples, validate on 2000 samples
# Epoch 1/50
#  - 4s - loss: 0.7403 - acc: 0.5055 - val_loss: 0.6893 - val_acc: 0.5290
# Epoch 2/50
#  - 3s - loss: 0.6918 - acc: 0.5320 - val_loss: 0.6798 - val_acc: 0.5870
# Epoch 3/50
#  - 3s - loss: 0.6783 - acc: 0.5733 - val_loss: 0.6557 - val_acc: 0.6020
# Epoch 4/50
#  - 3s - loss: 0.6524 - acc: 0.6202 - val_loss: 0.6558 - val_acc: 0.6050
# Epoch 5/50
#  - 3s - loss: 0.6397 - acc: 0.6325 - val_loss: 0.6357 - val_acc: 0.6380
# Epoch 6/50
#  - 3s - loss: 0.6228 - acc: 0.6578 - val_loss: 0.6370 - val_acc: 0.6495
# Epoch 7/50
#  - 3s - loss: 0.6088 - acc: 0.6695 - val_loss: 0.6240 - val_acc: 0.6525
# Epoch 8/50
#  - 3s - loss: 0.5898 - acc: 0.6885 - val_loss: 0.6113 - val_acc: 0.6645
# Epoch 9/50
#  - 3s - loss: 0.5631 - acc: 0.7098 - val_loss: 0.6785 - val_acc: 0.6280
# Epoch 10/50
#  - 3s - loss: 0.5352 - acc: 0.7337 - val_loss: 0.6512 - val_acc: 0.6385
# Epoch 11/50
#  - 3s - loss: 0.5005 - acc: 0.7587 - val_loss: 0.6811 - val_acc: 0.6395
# Epoch 12/50
#  - 3s - loss: 0.4430 - acc: 0.7933 - val_loss: 0.7127 - val_acc: 0.6630
# Epoch 13/50
#  - 3s - loss: 0.3957 - acc: 0.8242 - val_loss: 0.7221 - val_acc: 0.6545
# Epoch 14/50
#  - 3s - loss: 0.3300 - acc: 0.8600 - val_loss: 0.8328 - val_acc: 0.6505
# Epoch 15/50
#  - 3s - loss: 0.2720 - acc: 0.8873 - val_loss: 0.8983 - val_acc: 0.6300
# Epoch 16/50
#  - 3s - loss: 0.2241 - acc: 0.9112 - val_loss: 1.1035 - val_acc: 0.6450
# Epoch 17/50
#  - 3s - loss: 0.1897 - acc: 0.9213 - val_loss: 1.1517 - val_acc: 0.6415
# Epoch 18/50
#  - 3s - loss: 0.1545 - acc: 0.9425 - val_loss: 1.2304 - val_acc: 0.6435
# Epoch 19/50
#  - 3s - loss: 0.1394 - acc: 0.9472 - val_loss: 1.3106 - val_acc: 0.6430
# Epoch 20/50
#  - 3s - loss: 0.1236 - acc: 0.9538 - val_loss: 1.5982 - val_acc: 0.6175
# Epoch 21/50
#  - 3s - loss: 0.1137 - acc: 0.9562 - val_loss: 1.5001 - val_acc: 0.6440
# Epoch 22/50
#  - 3s - loss: 0.1087 - acc: 0.9615 - val_loss: 1.6607 - val_acc: 0.6205
# Epoch 23/50
#  - 3s - loss: 0.0999 - acc: 0.9650 - val_loss: 1.6882 - val_acc: 0.6250
# Epoch 24/50
#  - 3s - loss: 0.1004 - acc: 0.9643 - val_loss: 1.4760 - val_acc: 0.6395
# Epoch 25/50
#  - 3s - loss: 0.0862 - acc: 0.9695 - val_loss: 2.0224 - val_acc: 0.6065
# Epoch 26/50
#  - 3s - loss: 0.0878 - acc: 0.9660 - val_loss: 1.6598 - val_acc: 0.6410
# Epoch 27/50
#  - 3s - loss: 0.0778 - acc: 0.9688 - val_loss: 1.7504 - val_acc: 0.6310
# Epoch 28/50
#  - 3s - loss: 0.0810 - acc: 0.9708 - val_loss: 1.8397 - val_acc: 0.6345
# Epoch 29/50
#  - 3s - loss: 0.0765 - acc: 0.9723 - val_loss: 1.5864 - val_acc: 0.6420
# Epoch 30/50
#  - 3s - loss: 0.0745 - acc: 0.9737 - val_loss: 1.7773 - val_acc: 0.6335
# Epoch 31/50
#  - 3s - loss: 0.0721 - acc: 0.9767 - val_loss: 1.9606 - val_acc: 0.6395
# Epoch 32/50
#  - 3s - loss: 0.0656 - acc: 0.9768 - val_loss: 1.8349 - val_acc: 0.6340
# Epoch 33/50
#  - 3s - loss: 0.0751 - acc: 0.9723 - val_loss: 1.8699 - val_acc: 0.6115
# Epoch 34/50
#  - 3s - loss: 0.0653 - acc: 0.9800 - val_loss: 2.0654 - val_acc: 0.6345
# Epoch 35/50
#  - 3s - loss: 0.0653 - acc: 0.9783 - val_loss: 2.3240 - val_acc: 0.6040
# Epoch 36/50
#  - 3s - loss: 0.0654 - acc: 0.9763 - val_loss: 1.7114 - val_acc: 0.6465
# Epoch 37/50
#  - 3s - loss: 0.0691 - acc: 0.9762 - val_loss: 1.8365 - val_acc: 0.6380
# Epoch 38/50
#  - 3s - loss: 0.0704 - acc: 0.9770 - val_loss: 1.9321 - val_acc: 0.6360
# Epoch 39/50
#  - 3s - loss: 0.0673 - acc: 0.9805 - val_loss: 2.0128 - val_acc: 0.6260
# Epoch 40/50
#  - 3s - loss: 0.0573 - acc: 0.9810 - val_loss: 2.1276 - val_acc: 0.6320
# Epoch 41/50
#  - 3s - loss: 0.0571 - acc: 0.9798 - val_loss: 1.9237 - val_acc: 0.6450
# Epoch 42/50
#  - 3s - loss: 0.0668 - acc: 0.9788 - val_loss: 2.1957 - val_acc: 0.6310
# Epoch 43/50
#  - 3s - loss: 0.0561 - acc: 0.9807 - val_loss: 2.3701 - val_acc: 0.6355
# Epoch 44/50
#  - 3s - loss: 0.0545 - acc: 0.9823 - val_loss: 2.8135 - val_acc: 0.6435
# Epoch 45/50
#  - 3s - loss: 0.0580 - acc: 0.9802 - val_loss: 2.1508 - val_acc: 0.6240
# Epoch 46/50
#  - 3s - loss: 0.0622 - acc: 0.9807 - val_loss: 2.4221 - val_acc: 0.6325
# Epoch 47/50
#  - 3s - loss: 0.0549 - acc: 0.9822 - val_loss: 2.3827 - val_acc: 0.6325
# Epoch 48/50
#  - 3s - loss: 0.0551 - acc: 0.9812 - val_loss: 2.3524 - val_acc: 0.6335
# Epoch 49/50
#  - 3s - loss: 0.0514 - acc: 0.9838 - val_loss: 2.5730 - val_acc: 0.6475
# Epoch 50/50
#  - 3s - loss: 0.0609 - acc: 0.9798 - val_loss: 2.2807 - val_acc: 0.6530
# making predictions on test set...

# %%
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('VGG-16 Loss Trend')
plt.plot(loss, 'blue', label='Training Loss')
plt.plot(val_loss, 'green', label='Validation Loss')
plt.xticks(range(0,epochs)[0::2])
plt.legend()
plt.show()

# %%
for i in range(0,20):
    if predictions[i, 0] >= 0.75: 
        print('I am {:.2%} sure this is a Dog'.format(predictions[i][0]))
    else: 
        print('I am {:.2%} sure this is a Cat'.format(1-predictions[i][0]))
        
    plt.imshow(test2[i].T)
    plt.show()
# Out:
# I am 85.67% sure this is a Cat
# I am 98.59% sure this is a Dog
# I am 100.00% sure this is a Cat
# I am 83.80% sure this is a Dog
# I am 99.77% sure this is a Dog
# I am 99.35% sure this is a Cat
# I am 99.71% sure this is a Cat
# I am 93.95% sure this is a Cat
# I am 80.67% sure this is a Dog
# I am 99.91% sure this is a Cat
# I am 98.88% sure this is a Cat
# I am 91.15% sure this is a Cat
# I am 67.61% sure this is a Cat
# I am 100.00% sure this is a Dog
# I am 99.55% sure this is a Dog
# I am 97.51% sure this is a Cat
# I am 70.52% sure this is a Cat
# I am 98.55% sure this is a Dog
# I am 100.00% sure this is a Dog
# I am 52.61% sure this is a Cat
